# %%
# importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats

# %%
#reading the excel file 
data = pd.read_excel("D:\Projects Data Analytics For Students\Projects Data Analytics For Students\Project 2\Dataset - Mortgage Insurance.xls")

# %%
# checking the dataset
pd.set_option('display.max_columns', None)
data.head(50)
# Out:
#     Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  Loan_Type  Mosaic  \
# 0     1           918           A    36       3000.0  14.4  UnSecured      46
# 1     3           903           A   120      21000.0   7.9  secured        16
# 2     4          1060           X    78       7200.0   7.9  secured        17
# 3     6           839           B    60       8000.0  16.9  UnSecured      47
# 4     7          1057           X    60       7650.0   7.4  UnSecured      55
# 5     8           913           A   120      33000.0   9.4  secured        59
# 6     9           840           B    60       8000.0  15.9  UnSecured      12
# 7    10           961           X    60       5300.0  11.9  secured        43
# 8    11           901           A    60      12000.0  11.9  UnSecured      11
# 9    13           915           A    60       6000.0  12.9  UnSecured      49
# 10   17           840           B   120      10150.0  12.4  secured        24
# ...

# %%
#getting the info of dataset
data.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Columns: 59 entries, Ref to PPI_LCI
# dtypes: float64(3), int64(34), object(22)
# memory usage: 7.4+ MB

# %%
#checking the variables
data.columns
# Out:
# Index(['Ref', 'Credit_Score', 'Final_Grade', 'Term', 'Net_Advance', 'APR',
#        'Loan_Type', 'Mosaic', 'Mosaic_Class', 'Time_at_Address',
#        'Residential_Status', 'Telephone_Indicator', 'Number_of_Dependants',
#        'Marital_Status', 'Gender', 'Time_in_Employment', 'Employment_Status',
#        'Full_Part_Time_Empl_Ind', 'Perm_Temp_Empl_Ind', 'Income_Range',
#        'Current_Account', 'ACCESS_Card', 'VISA_Card', 'American_Express',
#        'Diners_Card', 'Cheque_Guarantee', 'Other_Credit_Store_Card',
#        'Time_with_Bank', 'Value_of_Property', 'Outstanding_Mortgage_Bal',
#        'Total_Outstanding_Balances', 'Bureau_Data___Monthly_Other_Co_R',
#        'Worst_History_CT', 'Payment_Method', 'Age',
#        'Total_outstanding_balance__mortg', 'Total___Public_Info___CCJ____ban',
#        'Total_value__Public_Info___CCJ__', 'Time_since_most_recent_Public_In',
#        'Total_value__CAIS_8_9s', 'Worst_status_L6m', 'Worst_CUrrent_Status',
# ...

# %%
# dividing the dataset 
sns.countplot(x= data['PPI'])
# Out:
# <AxesSubplot:xlabel='PPI', ylabel='count'>

# %%
#creating two separate database 
# data1 which has consumers with insurance 
data1 = data[data["PPI"] == 1]
# data0 which does not have any insurance
data0 = data[data["PPI"] == 0]

# %%
data['x']= data.index
data1['x1']= data1.index
data0['x0']= data0.index
# Out:
# C:\Users\sanket\AppData\Local\Temp/ipykernel_2760/797546534.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['x1']= data1.index
# C:\Users\sanket\AppData\Local\Temp/ipykernel_2760/797546534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data0['x0']= data0.index

# %%
#checking the data1
data1.head(50)
# Out:
#     Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  Loan_Type  Mosaic  \
# 1     3           903           A   120      21000.0   7.9  secured        16
# 2     4          1060           X    78       7200.0   7.9  secured        17
# 3     6           839           B    60       8000.0  16.9  UnSecured      47
# 4     7          1057           X    60       7650.0   7.4  UnSecured      55
# 5     8           913           A   120      33000.0   9.4  secured        59
# 6     9           840           B    60       8000.0  15.9  UnSecured      12
# 8    11           901           A    60      12000.0  11.9  UnSecured      11
# 9    13           915           A    60       6000.0  12.9  UnSecured      49
# 11   20           968           X   120      18000.0   8.4  secured        24
# 12   21           904           A    60      10000.0   8.7  UnSecured      46
# 13   23           924           A    44       8000.0   9.9  UnSecured      47
# ...

# %%
#describing the data1
data1.describe()
# Out:
#                 Ref  Credit_Score         Term   Net_Advance          APR  \
# count   9461.000000   9461.000000  9461.000000   9461.000000  9461.000000
# mean   20962.763239    871.023993    61.741888   7339.648635    19.271610
# std    12302.184694     85.057591    27.251238   6804.876018     9.901766
# min        3.000000    413.000000     6.000000    500.000000     6.400000
# 25%    10160.000000    812.000000    48.000000   3000.000000    10.900000
# 50%    21056.000000    870.000000    60.000000   5000.000000    17.400000
# 75%    31687.000000    931.000000    60.000000   9000.000000    25.900000
# max    42070.000000   1154.000000   300.000000  63350.000000    44.900000
#
#             Mosaic  Mosaic_Class  Time_at_Address  Number_of_Dependants  \
# count  9461.000000   9461.000000      9461.000000           9461.000000
# mean     31.381038      5.660924       129.082021              0.764507
# std      15.781346      5.169313       113.341008              1.127464
# ...

# %%
data1.to_excel('ppi1.xlsx', sheet_name='ppi')

# %%
# testing the categorical data

# %%
# current account
sns.countplot(x= data1['Current_Account'])
# Out:
# <AxesSubplot:xlabel='Current_Account', ylabel='count'>

# %%
data1.Current_Account.value_counts()
# Out:
# TRUE    9443
# FALS      18
# Name: Current_Account, dtype: int64

# %%
# Final_Grade
data1.Final_Grade.value_counts()
# Out:
# A    2649
# X    2007
# B    1409
# C     957
# D     869
# E     677
# F     479
# O     169
# R     160
# S      85
# Name: Final_Grade, dtype: int64

# %%
sns.countplot(x=data1['Final_Grade'])
# Out:
# <AxesSubplot:xlabel='Final_Grade', ylabel='count'>

# %%
# Loan_Type
data1.Loan_Type.value_counts()
# Out:
# UnSecured    7552
# secured      1909
# Name: Loan_Type, dtype: int64

# %%
sns.countplot(x=data1['Loan_Type'])
# Out:
# <AxesSubplot:xlabel='Loan_Type', ylabel='count'>

# %%
# Mosaic_Class
data1.Mosaic_Class.value_counts()
# Out:
# 4     1892
# 8     1889
# 7     1225
# 2     1106
# 3      908
# 6      606
# 1      542
# 10     400
# 5      339
# 11     309
# 9      224
# 99      21
# Name: Mosaic_Class, dtype: int64

# %%
sns.countplot(x=data1['Mosaic_Class'])
# Out:
# <AxesSubplot:xlabel='Mosaic_Class', ylabel='count'>

# %%
# Residential_Status
data1.Residential_Status.value_counts()
# Out:
# H    6882
# T    1996
# L     482
# R     101
# Name: Residential_Status, dtype: int64

# %%
sns.countplot(x=data1['Residential_Status'])
# Out:
# <AxesSubplot:xlabel='Residential_Status', ylabel='count'>

# %%
# Telephone_Indicator
data1.Telephone_Indicator.value_counts()
# Out:
# Y    8795
# N     666
# Name: Telephone_Indicator, dtype: int64

# %%
sns.countplot(x=data1['Telephone_Indicator'])
# Out:
# <AxesSubplot:xlabel='Telephone_Indicator', ylabel='count'>

# %%
# Marital_Status
data1.Marital_Status.value_counts()
# Out:
# M    5185
# S    3056
# D    1000
# W     220
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(x=data1['Marital_Status'])
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
# Gender
data1.Gender.value_counts()
# Out:
# M    5559
# F    3902
# Name: Gender, dtype: int64

# %%
sns.displot(data1['Gender'])

# %%
# Employment_Status
data1.Employment_Status.value_counts()
# Out:
# P    6047
# G    1684
# S    1058
# R     388
# D     236
# M      40
# U       4
# H       3
# T       1
# Name: Employment_Status, dtype: int64

# %%
sns.countplot(x=data1['Employment_Status'])
# Out:
# <AxesSubplot:xlabel='Employment_Status', ylabel='count'>

# %%
# Full_Part_Time_Empl_Ind
data1.Full_Part_Time_Empl_Ind.value_counts()
# Out:
# F    9424
# P      37
# Name: Full_Part_Time_Empl_Ind, dtype: int64

# %%
sns.countplot(x=data1['Full_Part_Time_Empl_Ind'])
# Out:
# <AxesSubplot:xlabel='Full_Part_Time_Empl_Ind', ylabel='count'>

# %%
# Perm_Temp_Empl_Ind
data1.Perm_Temp_Empl_Ind.value_counts()
# Out:
# P    9447
# T      14
# Name: Perm_Temp_Empl_Ind, dtype: int64

# %%
sns.countplot(x= data1['Perm_Temp_Empl_Ind'])
# Out:
# <AxesSubplot:xlabel='Perm_Temp_Empl_Ind', ylabel='count'>

# %%
# Bankruptcy_Detected__SP_
data1.Bankruptcy_Detected__SP_.value_counts()
# Out:
# N    9438
# Y      19
# T       4
# Name: Bankruptcy_Detected__SP_, dtype: int64

# %%
sns.countplot(x= data1['Bankruptcy_Detected__SP_'])
# Out:
# <AxesSubplot:xlabel='Bankruptcy_Detected__SP_', ylabel='count'>

# %%
# CIFAS_detected
data1.CIFAS_detected.value_counts()
# Out:
# N    9402
# Y      55
# T       4
# Name: CIFAS_detected, dtype: int64

# %%
sns.countplot(x=data1['CIFAS_detected'])
# Out:
# <AxesSubplot:xlabel='CIFAS_detected', ylabel='count'>

# %%
# Payment_Method
data1.Payment_Method.value_counts()
# Out:
# D    9409
# C      36
# S      16
# Name: Payment_Method, dtype: int64

# %%
sns.displot(x=data1['Payment_Method'])

# %%
# checking mean , std , mode 
data1.describe()
# Out:
#                 Ref  Credit_Score         Term   Net_Advance          APR  \
# count   9461.000000   9461.000000  9461.000000   9461.000000  9461.000000
# mean   20962.763239    871.023993    61.741888   7339.648635    19.271610
# std    12302.184694     85.057591    27.251238   6804.876018     9.901766
# min        3.000000    413.000000     6.000000    500.000000     6.400000
# 25%    10160.000000    812.000000    48.000000   3000.000000    10.900000
# 50%    21056.000000    870.000000    60.000000   5000.000000    17.400000
# 75%    31687.000000    931.000000    60.000000   9000.000000    25.900000
# max    42070.000000   1154.000000   300.000000  63350.000000    44.900000
#
#             Mosaic  Mosaic_Class  Time_at_Address  Number_of_Dependants  \
# count  9461.000000   9461.000000      9461.000000           9461.000000
# mean     31.381038      5.660924       129.082021              0.764507
# std      15.781346      5.169313       113.341008              1.127464
# ...

# %%
data1.mode().head(1)
# Out:
#    Ref  Credit_Score Final_Grade  Term  Net_Advance  APR  Loan_Type  Mosaic  \
# 0    3         953.0           A  60.0       5000.0  7.9  UnSecured    44.0
#
#    Mosaic_Class  Time_at_Address Residential_Status Telephone_Indicator  \
# 0           4.0             60.0                  H                   Y
#
#    Number_of_Dependants Marital_Status Gender  Time_in_Employment  \
# 0                   0.0              M      M                60.0
#
#   Employment_Status Full_Part_Time_Empl_Ind Perm_Temp_Empl_Ind  Income_Range  \
# 0                 P                       F                  P           6.0
#
#   Current_Account ACCESS_Card VISA_Card American_Express Diners_Card  \
# 0            TRUE       FALSE     TRUE             FALSE       FALSE
#
#   Cheque_Guarantee Other_Credit_Store_Card  Time_with_Bank  Value_of_Property  \
# 0             TRUE                  FALSE            240.0           120000.0
#
#    Outstanding_Mortgage_Bal  Total_Outstanding_Balances  \
# ...

# %%
data1.mode()
#data1['Credit_Score'].mean()
# Out:
#         Ref  Credit_Score Final_Grade  Term  Net_Advance  APR  Loan_Type  \
# 0         3         953.0           A  60.0       5000.0  7.9  UnSecured
# 1         4           NaN         NaN   NaN          NaN  NaN        NaN
# 2         6           NaN         NaN   NaN          NaN  NaN        NaN
# 3         7           NaN         NaN   NaN          NaN  NaN        NaN
# 4         8           NaN         NaN   NaN          NaN  NaN        NaN
# ...     ...           ...         ...   ...          ...  ...        ...
# 9456  42021           NaN         NaN   NaN          NaN  NaN        NaN
# 9457  42035           NaN         NaN   NaN          NaN  NaN        NaN
# 9458  42036           NaN         NaN   NaN          NaN  NaN        NaN
# 9459  42069           NaN         NaN   NaN          NaN  NaN        NaN
# 9460  42070           NaN         NaN   NaN          NaN  NaN        NaN
#
#       Mosaic  Mosaic_Class  Time_at_Address Residential_Status  \
# ...

# %%
# Credit_Score
sns.displot(x=data1['Credit_Score'],binwidth=10)

# %%
a = data1['Credit_Score'].mean()
b = data1['Credit_Score'].std()*2

print('range',a -b , 'to', a + b)
# Out:
# range 700.9088108238594 to 1041.1391756469152

# %%
# Term
sns.displot(x=data1['Term'],binwidth=12)

# %%
a = data1['Term'].mean()
b = data1['Term'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range 7.239411168917329 to 116.24436433050134

# %%
#Net_Advance
sns.displot(x=data1['Net_Advance'],binwidth=10000)

# %%
#APR
sns.displot(x=data1['APR'],binwidth=5)

# %%
# Mosaic
sns.displot(x=data1['Mosaic'],binwidth=10)

# %%
a = data1['Mosaic'].mean()
b = data1['Mosaic'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -0.18165417893085944 to 62.943730069428696

# %%
# Mosaic_Class
sns.displot(x=data1['Mosaic_Class'])

# %%
# Time_at_Address
sns.displot(x=data1['Time_at_Address'],binwidth=12)

# %%
a = data1['Time_at_Address'].mean()
b = data1['Time_at_Address'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -97.59999583508468 to 355.7640376911253

# %%
# Number_of_Dependants
sns.countplot(x=data1['Number_of_Dependants'])
# Out:
# <AxesSubplot:xlabel='Number_of_Dependants', ylabel='count'>

# %%
a = data1['Number_of_Dependants'].mean()
b = data1['Number_of_Dependants'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -1.49042156910027 to 3.019435415416727

# %%
# Time_in_Employment
sns.displot(data1['Time_in_Employment'],binwidth=12)

# %%
a = data1['Time_in_Employment'].mean()
b = data1['Time_in_Employment'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -78.58119086931525 to 281.65465033448805

# %%
# Income_Range
sns.displot(data1['Income_Range'])

# %%
a = data1['Income_Range'].mean()
b = data1['Income_Range'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range 1.4199074198996664 to 7.389097970651016

# %%
# Time_with_Bank
sns.displot(data1['Time_with_Bank'],binwidth=12)

# %%
a = data1['Time_with_Bank'].mean()
b = data1['Time_with_Bank'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -13.76868171268407 to 409.6467072913755

# %%
# Value_of_Property
sns.displot(data1['Value_of_Property'])

# %%
a = data1['Value_of_Property'].mean()
b = data1['Value_of_Property'].std()
print('range',a -b , 'to', a + b)
# Out:
# range 57784.555283759444 to 244970.63296272611

# %%
# Outstanding_Mortgage_Bal
sns.displot(data1['Outstanding_Mortgage_Bal'])

# %%
a = data1['Outstanding_Mortgage_Bal'].mean()
b = data1['Outstanding_Mortgage_Bal'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -83099.54022406507 to 205982.47268363595

# %%
# Total_Outstanding_Balances
sns.displot(data1['Total_Outstanding_Balances'])

# %%
a = data1['Total_Outstanding_Balances'].mean()
b = data1['Total_Outstanding_Balances'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -84458.36361802791 to 221190.58389072635

# %%
# Bureau_Data___Monthly_Other_Co_R
sns.displot(data1['Bureau_Data___Monthly_Other_Co_R'])

# %%
a = data1['Bureau_Data___Monthly_Other_Co_R'].mean()
b = data1['Bureau_Data___Monthly_Other_Co_R'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -549.9775324462854 to 1629.0169574542128

# %%
# Age
sns.displot(data1['Age'],binwidth=5)

# %%
a = data1['Age'].mean()
b = data1['Age'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range 22.82307838302045 to 66.71439122907128

# %%
sns.displot(data1['Total___Public_Info___CCJ____ban'])

# %%
sns.displot(data1['Total_value__Public_Info___CCJ__'])

# %%
sns.displot(data1['Time_since_most_recent_Public_In'])

# %%
sns.displot(data1['Total_value__CAIS_8_9s'])

# %%
sns.displot(data1['Worst_status_L6m'])

# %%
sns.displot(data1['Worst_CUrrent_Status'])

# %%
sns.displot(data1['__of_status_3_s_L6m'])

# %%
sns.displot(data1['Searches___Total___L6m'])

# %%
sns.displot(data1['Years_on_ER_for_SP'])

# %%
sns.displot(data1['Total___outstanding_CCJ_s'])

# %%
sns.displot(data1['Total_outstanding_balance___excl'])

# %%
a = data1['Total_outstanding_balance___excl'].mean()
b = data1['Total_outstanding_balance___excl'].std()*2
print('range',a -b , 'to', a + b)
# Out:
# range -142.0227554050425 to 405.1943017532086

# %%
sns.countplot(x=data1['Total___of_accounts'])
# Out:
# <AxesSubplot:xlabel='Total___of_accounts', ylabel='count'>

# %%
sns.displot(data1['Time_since_most_recent_outstandi'])

# %%
sns.displot(data1['code'])

# %%
# find the possible customer

# %%
consumer = data0[(data0["Current_Account"] == 'TRUE')& 
                 (data0["Bankruptcy_Detected__SP_"] == 'N') &
                 (data0["Perm_Temp_Empl_Ind"] == 'P')& 
                 (data0["Full_Part_Time_Empl_Ind"] == 'F') &
                 (data0["CIFAS_detected"] == 'N') &
                 (data0["Payment_Method"] == 'D') &
                 (data0["Credit_Score"].between( 700 ,1040)) &
                 (data0["Value_of_Property"].between( 57785  ,244970)) & 
                 (data0["Total_Outstanding_Balances"].between( 0  ,221190)) &
                 (data0["Mosaic"].between( 0  ,63)) &
                 (data0["Time_at_Address"].between( 0  ,355))&
                 (data0["Income_Range"].between(1.4 ,7.4)) &
                 (data0["Age"].between(23 ,68)) & 
                 (data0["Outstanding_Mortgage_Bal"].between(0 ,205982)) &
                 (data0["Time_with_Bank"].between(0 ,410))&
                 (data0["Bureau_Data___Monthly_Other_Co_R"].between(0 ,1630))&
                 (data0["Term"].between(6 ,116))  ]

# %%
consumer
# Out:
#          Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  Loan_Type  \
# 0          1           918           A    36      3000.00  14.4  UnSecured
# 7         10           961           X    60      5300.00  11.9  secured
# 23        44           966           X    48      8000.00   7.9  UnSecured
# 26        54           789           D    60      2000.00  27.9  UnSecured
# 42        93           965           X    60      8125.00   6.9  UnSecured
# ...      ...           ...         ...   ...          ...   ...        ...
# 16372  42048           937           A    24      1000.00  19.9  UnSecured
# 16373  42056           948           X    48      1000.00  19.9  UnSecured
# 16374  42057           969           X    60      6115.38   9.9  UnSecured
# 16377  42064           915           A    36      1000.00  21.9  UnSecured
# 16379  42068           922           A    60      7500.00   7.9  UnSecured
#
#        Mosaic  Mosaic_Class  Time_at_Address Residential_Status  \
# ...

# %%
consumer.to_excel('consumer_base.xlsx', sheet_name='consumer')
