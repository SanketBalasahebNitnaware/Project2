# %%
# importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats

# %%
#reading the excel file 
df = pd.read_excel("C:\\Users\\sanket\\ppi1.xlsx")
data = pd.read_excel("C:\\Users\\sanket\\Project2\\consumer_base.xlsx")
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#    Unnamed: 0  Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  \
# 0           1    3           903           A   120      21000.0   7.9
# 1           2    4          1060           X    78       7200.0   7.9
# 2           3    6           839           B    60       8000.0  16.9
# 3           4    7          1057           X    60       7650.0   7.4
# 4           5    8           913           A   120      33000.0   9.4
# 5           6    9           840           B    60       8000.0  15.9
# 6           8   11           901           A    60      12000.0  11.9
# 7           9   13           915           A    60       6000.0  12.9
# 8          11   20           968           X   120      18000.0   8.4
# 9          12   21           904           A    60      10000.0   8.7
#
#    Loan_Type  Mosaic  Mosaic_Class  Time_at_Address Residential_Status  \
# 0  secured        16             3              288                  H
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0           Ref  Credit_Score         Term   Net_Advance  \
# count   9461.000000   9461.000000   9461.000000  9461.000000   9461.000000
# mean    8112.010992  20962.763239    871.023993    61.741888   7339.648635
# std     4790.105334  12302.184694     85.057591    27.251238   6804.876018
# min        1.000000      3.000000    413.000000     6.000000    500.000000
# 25%     3895.000000  10160.000000    812.000000    48.000000   3000.000000
# 50%     8100.000000  21056.000000    870.000000    60.000000   5000.000000
# 75%    12285.000000  31687.000000    931.000000    60.000000   9000.000000
# max    16381.000000  42070.000000   1154.000000   300.000000  63350.000000
#
#                APR       Mosaic  Mosaic_Class  Time_at_Address  \
# count  9461.000000  9461.000000   9461.000000      9461.000000
# mean     19.271610    31.381038      5.660924       129.082021
# std       9.901766    15.781346      5.169313       113.341008
# ...

# %%
df.groupby(["category"]).size()
# Out:
# category
# JOINT      647
# Joint      578
# LCI       1972
# Single    6264
# dtype: int64

# %%
df.groupby(["prdt_desc"]).size()
# Out:
# prdt_desc
# 1st Cust - LASCI / 2nd Cust - LASU      52
# 1st Cust - LASCI / 2nd Cust - LCI      129
# 1st Cust - LASU / 2nd Cust - L           2
# 1st Cust - LASU / 2nd Cust - LASCI      44
# 1st Cust - LASU / 2nd Cust - LCI       387
# 1st Cust LASCI / 2nd Cust LASU          29
# 1st Cust LASU / 2nd Cust LASCI          19
# JOINT LASCI                             69
# JOINT LASU                             285
# JOINT LIFE & CRITICAL ILLNESS          571
# LASCI                                 1170
# LASCI JOINT                            123
# LASU                                  3889
# LASU JOINT                             604
# LIFE & CRITICAL ILLNESS               1972
# dtype: int64

# %%
# cleaning 
df.replace(to_replace="JOINT", value="Joint",inplace=True)
df.replace(to_replace="1st Cust LASCI / 2nd Cust LASU", value="1st Cust - LASCI / 2nd Cust - LASU",inplace=True)
df.replace(to_replace="1st Cust LASU / 2nd Cust LASCI", value="1st Cust - LASU / 2nd Cust - LASCI",inplace=True)

# %%
df.groupby(["category"]).size()
# Out:
# category
# Joint     1225
# LCI       1972
# Single    6264
# dtype: int64

# %%
df.groupby(["prdt_desc"]).size()
# Out:
# prdt_desc
# 1st Cust - LASCI / 2nd Cust - LASU      81
# 1st Cust - LASCI / 2nd Cust - LCI      129
# 1st Cust - LASU / 2nd Cust - L           2
# 1st Cust - LASU / 2nd Cust - LASCI      63
# 1st Cust - LASU / 2nd Cust - LCI       387
# JOINT LASCI                             69
# JOINT LASU                             285
# JOINT LIFE & CRITICAL ILLNESS          571
# LASCI                                 1170
# LASCI JOINT                            123
# LASU                                  3889
# LASU JOINT                             604
# LIFE & CRITICAL ILLNESS               1972
# dtype: int64

# %%
df.groupby(["Marital_Status","category"]).size()
# Out:
# Marital_Status  category
# D               Joint         24
#                 LCI          292
#                 Single       684
# M               Joint       1013
#                 LCI         1001
#                 Single      3171
# S               Joint        188
#                 LCI          566
#                 Single      2302
# W               LCI          113
#                 Single       107
# dtype: int64

# %%
df.groupby(["category","prdt_desc","Marital_Status"]).size()
# Out:
# category  prdt_desc                           Marital_Status
# Joint     1st Cust - LASCI / 2nd Cust - LASU  M                   73
#                                               S                    8
#           1st Cust - LASU / 2nd Cust - LASCI  D                    2
#                                               M                   51
#                                               S                   10
#           JOINT LASCI                         D                    2
#                                               M                   59
#                                               S                    8
#           JOINT LASU                          D                    7
#                                               M                  216
#                                               S                   62
#           LASCI JOINT                         D                    1
#                                               M                  111
# ...

# %%
M = df[(df["Marital_Status"] == "M")]
S = df[(df["Marital_Status"] == "S")]
D = df[(df["Marital_Status"] == "D")]
W = df[(df["Marital_Status"] == "W")]

# %%
M.groupby(["Employment_Status","prdt_desc"]).size()
# Out:
# Employment_Status  prdt_desc
# D                  JOINT LIFE & CRITICAL ILLNESS           62
#                    LIFE & CRITICAL ILLNESS                 56
# G                  1st Cust - LASCI / 2nd Cust - LASU      17
#                    1st Cust - LASCI / 2nd Cust - LCI       12
#                    1st Cust - LASU / 2nd Cust - LASCI      12
#                    1st Cust - LASU / 2nd Cust - LCI        42
#                    JOINT LASCI                             15
#                    JOINT LASU                              42
#                    JOINT LIFE & CRITICAL ILLNESS           83
#                    LASCI                                   73
#                    LASCI JOINT                             22
#                    LASU                                   280
#                    LASU JOINT                             101
#                    LIFE & CRITICAL ILLNESS                177
# H                  JOINT LIFE & CRITICAL ILLNESS            2
# ...

# %%
S.groupby(["Employment_Status","prdt_desc"]).size()
# Out:
# Employment_Status  prdt_desc
# D                  JOINT LIFE & CRITICAL ILLNESS           12
#                    LIFE & CRITICAL ILLNESS                 49
# G                  1st Cust - LASCI / 2nd Cust - LASU       1
#                    1st Cust - LASU / 2nd Cust - LASCI       3
#                    1st Cust - LASU / 2nd Cust - LCI         7
#                    JOINT LASU                              14
#                    JOINT LIFE & CRITICAL ILLNESS           16
#                    LASCI                                   74
#                    LASCI JOINT                              3
#                    LASU                                   274
#                    LASU JOINT                              14
#                    LIFE & CRITICAL ILLNESS                121
# M                  1st Cust - LASCI / 2nd Cust - LASU       1
#                    JOINT LIFE & CRITICAL ILLNESS            1
#                    LASCI                                    4
# ...

# %%
D.groupby(["Employment_Status","prdt_desc"]).size()
# Out:
# Employment_Status  prdt_desc
# D                  JOINT LIFE & CRITICAL ILLNESS           1
#                    LIFE & CRITICAL ILLNESS                37
# G                  JOINT LASCI                             1
#                    LASCI                                  39
#                    LASCI JOINT                             1
#                    LASU                                  127
#                    LASU JOINT                              3
#                    LIFE & CRITICAL ILLNESS                73
# M                  LIFE & CRITICAL ILLNESS                 5
# P                  1st Cust - LASU / 2nd Cust - LASCI      2
#                    1st Cust - LASU / 2nd Cust - LCI        1
#                    JOINT LASU                              7
#                    JOINT LIFE & CRITICAL ILLNESS           5
#                    LASCI                                  84
#                    LASU                                  354
# ...

# %%
W.groupby(["Employment_Status","prdt_desc"]).size()
# Out:
# Employment_Status  prdt_desc
# D                  LIFE & CRITICAL ILLNESS          15
# G                  LASCI                             8
#                    LASU                             15
#                    LIFE & CRITICAL ILLNESS          11
# M                  LIFE & CRITICAL ILLNESS           1
# P                  LASCI                             7
#                    LASU                             63
#                    LIFE & CRITICAL ILLNESS          11
# R                  JOINT LIFE & CRITICAL ILLNESS     3
#                    LIFE & CRITICAL ILLNESS          71
# S                  LASCI                            10
#                    LIFE & CRITICAL ILLNESS           4
# dtype: int64

# %%
sns.relplot(x="Age",y="Credit_Score",col="Marital_Status",row="prdt_desc",hue="Employment_Status",data=df)

# %%
data
# Out:
#       Unnamed: 0    Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  \
# 0              0      1           918           A    36      3000.00  14.4
# 1              7     10           961           X    60      5300.00  11.9
# 2             23     44           966           X    48      8000.00   7.9
# 3             26     54           789           D    60      2000.00  27.9
# 4             42     93           965           X    60      8125.00   6.9
# ...          ...    ...           ...         ...   ...          ...   ...
# 3736       16372  42048           937           A    24      1000.00  19.9
# 3737       16373  42056           948           X    48      1000.00  19.9
# 3738       16374  42057           969           X    60      6115.38   9.9
# 3739       16377  42064           915           A    36      1000.00  21.9
# 3740       16379  42068           922           A    60      7500.00   7.9
#
# ...

# %%
# removing unwanted columns
data.drop(["Unnamed: 0","x0"],axis=1)
# Out:
#         Ref  Credit_Score Final_Grade  Term  Net_Advance   APR  Loan_Type  \
# 0         1           918           A    36      3000.00  14.4  UnSecured
# 1        10           961           X    60      5300.00  11.9  secured
# 2        44           966           X    48      8000.00   7.9  UnSecured
# 3        54           789           D    60      2000.00  27.9  UnSecured
# 4        93           965           X    60      8125.00   6.9  UnSecured
# ...     ...           ...         ...   ...          ...   ...        ...
# 3736  42048           937           A    24      1000.00  19.9  UnSecured
# 3737  42056           948           X    48      1000.00  19.9  UnSecured
# 3738  42057           969           X    60      6115.38   9.9  UnSecured
# 3739  42064           915           A    36      1000.00  21.9  UnSecured
# 3740  42068           922           A    60      7500.00   7.9  UnSecured
#
#       Mosaic  Mosaic_Class  Time_at_Address Residential_Status  \
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0           Ref  Credit_Score         Term   Net_Advance  \
# count   3741.000000   3741.000000   3741.000000  3741.000000   3741.000000
# mean    8408.706228  21729.450414    882.721732    50.625501   5797.678431
# std     4672.306260  11988.601888     78.139108    14.981132   3672.449245
# min        0.000000      1.000000    700.000000    10.000000    500.000000
# 25%     4371.000000  11429.000000    824.000000    36.000000   3000.000000
# 50%     8411.000000  21830.000000    882.000000    60.000000   5000.000000
# 75%    12464.000000  32113.000000    944.000000    60.000000   7500.000000
# max    16379.000000  42068.000000   1039.000000    96.000000  35000.000000
#
#                APR       Mosaic  Mosaic_Class  Time_at_Address  \
# count  3741.000000  3741.000000   3741.000000      3741.000000
# mean     19.037477    29.368885      5.155841        98.560545
# std       9.087845    15.667492      2.733147        83.069299
# ...

# %%
#creating list of products
LASU = []
LASCI = []
LCI = []
LASU_JOINT = []
LASCI_JOINT = []
LCI_JOINT = []

#fuction to write the product to cross sell to customers

for i in range(len(data.Ref)): 
    if data['Employment_Status'][i] == "D":
        if data['Marital_Status'][i] == "M":
            LCI_JOINT.append(data["Ref"][i])
        elif data['Marital_Status'][i] == "S":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LCI.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "S":
        if data['Marital_Status'][i] == "M":
            LASCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LASCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LASCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LASCI.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "G":
        if data['Marital_Status'][i] == "M":
            LASU.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LASU_JOINT.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LASU_JOINT.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LASU_JOINT.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "M":
        if data['Marital_Status'][i] == "M":
            LASU_JOINT.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LASU.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LCI.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "P":
        if data['Marital_Status'][i] == "M":
            LASU.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LASU.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LASU.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LASU.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "H":
        if data['Marital_Status'][i] == "M":
            LCI_JOINT.append((data["Ref"][i]))
     
    elif data['Employment_Status'][i] == "T":
        if data['Marital_Status'][i] == "M":
            LCI_JOINT.append((data["Ref"][i]))
            
    elif data['Employment_Status'][i] == "U":
        if data['Marital_Status'][i] == "M":
            LCI_JOINT.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LCI.append((data["Ref"][i]))
    
    elif data['Employment_Status'][i] == "R":
        if data['Marital_Status'][i] == "M":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "S":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "D":
            LCI.append((data["Ref"][i]))
        elif data['Marital_Status'][i] == "W":
            LCI.append((data["Ref"][i]))       
    

#print(data0["Ref"][i],data0['Marital_Status'][i],data0['Employment_Status'][i])
print(LCI_JOINT)
print(LCI)
print(LASU)
print(LASCI)
print(LASU_JOINT)
print(LASCI_JOINT)
# Out:
# [317, 356, 6570, 7098, 7547, 9506, 9921, 9984, 12521, 14321, 16150, 17026, 19108, 22996, 24901, 25572, 25854, 26848, 27269, 30730, 31000, 31100, 31176, 40211, 41329]
# [1162, 1340, 1495, 1795, 2710, 3419, 4212, 4648, 5869, 6559, 7280, 8188, 8862, 9163, 9202, 9218, 9516, 9729, 10175, 10358, 10491, 10946, 11294, 11525, 12076, 12592, 12686, 13033, 13741, 13927, 14286, 14418, 14420, 15494, 15826, 15924, 15928, 16290, 16497, 17283, 17297, 17309, 17326, 18040, 18095, 19920, 20092, 20148, 21664, 22011, 22117, 22685, 22732, 23222, 23465, 24009, 24258, 24455, 24555, 24557, 24805, 25221, 25559, 25775, 26018, 26643, 26840, 26892, 27357, 28398, 28749, 29543, 29747, 29828, 30368, 31424, 32269, 32595, 33143, 34258, 34623, 36904, 37375, 38833, 39299, 39322, 39719, 40567, 40892, 41098]
# ...

# %%
product_to_offer = pd.DataFrame({ "LCI":pd.Series(LCI),"LCI_JOINT":pd.Series(LCI_JOINT),"LASU":pd.Series(LASU),"LASCI":pd.Series(LASCI),"LASU_JOINT":pd.Series(LASU_JOINT),"LASCI_JOINT":pd.Series(LASCI_JOINT)})
# Out:
# C:\Users\sanket\AppData\Local\Temp/ipykernel_11680/230288163.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   product_to_offer = pd.DataFrame({ "LCI":pd.Series(LCI),"LCI_JOINT":pd.Series(LCI_JOINT),"LASU":pd.Series(LASU),"LASCI":pd.Series(LASCI),"LASU_JOINT":pd.Series(LASU_JOINT),"LASCI_JOINT":pd.Series(LASCI_JOINT)})

# %%
product_to_offer
# Out:
#          LCI  LCI_JOINT   LASU  LASCI  LASU_JOINT  LASCI_JOINT
# 0     1162.0      317.0     10    1.0        93.0          NaN
# 1     1340.0      356.0     44  133.0       234.0          NaN
# 2     1495.0     6570.0     54  194.0       257.0          NaN
# 3     1795.0     7098.0     96  385.0       321.0          NaN
# 4     2710.0     7547.0     97  390.0       366.0          NaN
# ...      ...        ...    ...    ...         ...          ...
# 2789     NaN        NaN  42038    NaN         NaN          NaN
# 2790     NaN        NaN  42048    NaN         NaN          NaN
# 2791     NaN        NaN  42056    NaN         NaN          NaN
# 2792     NaN        NaN  42057    NaN         NaN          NaN
# 2793     NaN        NaN  42068    NaN         NaN          NaN
#
# [2794 rows x 6 columns]

# %%
from openpyxl import load_workbook

path = r"C:\Users\sanket\consumer_base.xlsx"

book = load_workbook(path)
writer = pd.ExcelWriter(path, engine = 'openpyxl')
writer.book = book

product_to_offer.to_excel(writer, sheet_name = 'product_to_offer')

writer.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/1699990928.py in <module>
#       3 path = r"C:\Users\sanket\consumer_base.xlsx"
#       4
# ----> 5 book = load_workbook(path)
#       6 writer = pd.ExcelWriter(path, engine = 'openpyxl')
#       7 writer.book = book
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# ...
